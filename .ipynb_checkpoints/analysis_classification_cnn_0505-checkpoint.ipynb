# %%
import pandas as pd
import os
import numpy as np

# %%
PATH = "./wandb_classification_cnn_0505.csv"
dataset = pd.read_csv(PATH)
del dataset["Created"], dataset["Runtime"], dataset["GradC"], dataset["act_B"], dataset["act_F"], dataset["epochs"], dataset["fw_bn"], dataset["loss_scale_ssl"]
dataset = dataset[dataset["State"]=="finished"]
dataset = dataset[dataset["architecture"]=="cnn_pool"]

# %%
ds = dataset[dataset["dataset"] == "CIFAR10"]
print("show the highest validation hyperparameters")
# Out:
#                  Name  val_acc  test_acc     State architecture  batchsize  \
# 0     CIFAR10_BP_none   0.8902    0.8324  finished     cnn_pool         32
# 1     CIFAR10_BP_none   0.8898    0.8493  finished     cnn_pool         64
# 2     CIFAR10_BP_none   0.8878    0.8692  finished     cnn_pool        128
# 3     CIFAR10_BP_none   0.8870    0.8504  finished     cnn_pool         64
# 4     CIFAR10_BP_none   0.8866    0.8405  finished     cnn_pool         64
# ..                ...      ...       ...       ...          ...        ...
# 930   CIFAR10_BP_none   0.7168    0.7475  finished     cnn_pool        128
# 932  CIFAR10_CCL_none   0.7146    0.7298  finished     cnn_pool        256
# 936  CIFAR10_CCL_none   0.7102    0.7189  finished     cnn_pool        256
# 937  CIFAR10_CCL_none   0.7086    0.7224  finished     cnn_pool        256
# 938  CIFAR10_CCL_none   0.7078    0.7195  finished     cnn_pool        256
#
#      bn_affine  dataset  grad_clip_F  lr_F method  mmt_F      wd_F  \
# 0            0  CIFAR10          0.0  0.03     BP    0.5  0.000010
# 1            0  CIFAR10          3.0  0.03     BP    0.9  0.000010
# 2            0  CIFAR10          0.0  0.03     BP    0.9  0.000010
# 3            0  CIFAR10          0.0  0.01     BP    0.9  0.000010
# 4            0  CIFAR10          0.0  0.01     BP    0.9  0.000010
# ..         ...      ...          ...   ...    ...    ...       ...
# 930          0  CIFAR10          1.0  0.01     BP    0.5  0.000010
# 932          1  CIFAR10          0.3  0.30    CCL    0.2  0.000001
# 936          1  CIFAR10          0.3  0.30    CCL    0.2  0.000001
# 937          1  CIFAR10          1.0  0.30    CCL    0.2  0.000001
# 938          1  CIFAR10          1.0  0.30    CCL    0.2  0.000001
#
#      loss_scale_C  seed
# 0             0.5     1
# 1             0.5     1
# 2             0.5     1
# 3             0.5     3
# 4             0.5     1
# ..            ...   ...
# 930           0.5     1
# 932           1.0     1
# 936           1.0     0
# 937           1.0     0
# 938           1.0     1
#
# [804 rows x 15 columns]

# %%
# MNIST

ds = dataset[dataset["dataset"] == "MNIST"]
del ds["Runtime"]
ds = ds[ds.epochs_backward == 5]
ds = ds[(ds.loss_feedback != "DRL") | ((ds.loss_feedback == "DRL") & (ds.learning_rate == 4) & (ds.learning_rate_backward == 0.0002) & (ds.stepsize == 0.04))]
ds = ds[(ds.loss_feedback != "L-DRL") | ((ds.loss_feedback == "L-DRL") & (ds.learning_rate == 4) & (ds.learning_rate_backward == 0.0002) & (ds.stepsize == 0.04))]
ds = ds[~ds.duplicated(subset=["Name", "loss_feedback", "seed", "learning_rate", "learning_rate_backward", "stepsize"])]
pd.pivot_table(ds, values='test accuracy', index=['algorithm', 'loss_feedback'], columns=['dataset'], aggfunc="mean")
# Out:
# dataset                    MNIST
# algorithm loss_feedback
# BP        DTP            0.98065
# DTP       DRL            0.93250
#           DTP            0.97308
#           L-DRL          0.93284
# DTP-BN    DTP            0.97110
# FWDTP     DTP            0.89836
# FWDTP-BN  DTP            0.97204

# %%
pd.pivot_table(ds, values='test accuracy', index=['algorithm', 'loss_feedback'], columns=['dataset'], aggfunc="std")
# Out:
# dataset                     MNIST
# algorithm loss_feedback
# BP        DTP            0.004036
# DTP       DRL            0.000914
#           DTP            0.000626
#           L-DRL          0.004496
# DTP-BN    DTP            0.001490
# FWDTP     DTP            0.001146
# FWDTP-BN  DTP            0.001424

# %%
# MNIST
ds = dataset[dataset["dataset"] == "FashionMNIST"]
del ds["Runtime"]
ds = ds[ds.epochs_backward == 5]
ds = ds[(ds.algorithm != "BP") | ((ds.algorithm == "BP") & (ds.learning_rate == 0.1))]
ds = ds[(ds.loss_feedback != "DRL") | ((ds.loss_feedback == "DRL") & (ds.learning_rate == 4) & (ds.learning_rate_backward == 0.002) & (ds.stepsize == 0.008))]
ds = ds[(ds.loss_feedback != "L-DRL") | ((ds.loss_feedback == "L-DRL") & (ds.learning_rate == 2) & (ds.learning_rate_backward == 0.001) & (ds.stepsize == 0.02))]
ds = ds[~ds.duplicated(subset=["Name", "loss_feedback", "seed", "learning_rate", "learning_rate_backward", "stepsize"])]
pd.pivot_table(ds, values='test accuracy', index=['algorithm', 'loss_feedback'], columns=['dataset'], aggfunc="mean")
# Out:
# dataset                  FashionMNIST
# algorithm loss_feedback
# BP        DTP                 0.89238
# DTP       DRL                 0.83342
#           DTP                 0.88272
#           L-DRL               0.83514
# FWDTP-BN  DTP                 0.88278

# %%
pd.pivot_table(ds, values='test accuracy', index=['algorithm', 'loss_feedback'], columns=['dataset'], aggfunc="std")
# Out:
# dataset                  FashionMNIST
# algorithm loss_feedback
# BP        DTP                0.007128
# DTP       DRL                0.001785
#           DTP                0.003154
#           L-DRL              0.002004
# FWDTP-BN  DTP                0.002333

# %%
ds = dataset[dataset["dataset"] == "CIFAR10"]
del ds["Runtime"]
ds["algorithm"].unique()
ds = ds[ds.epochs_backward == 5]
ds = ds[(ds.algorithm != "BP") | ((ds.algorithm == "BP") & (ds.learning_rate == 0.02))]
# pd.pivot_table(ds[ds.algorithm == "BP"], values='test accuracy', index=['learning_rate'], columns=['dataset'], aggfunc="mean")
ds = ds[(ds.loss_feedback != "DRL") | ((ds.loss_feedback == "DRL") & (ds.learning_rate == 2) & (ds.learning_rate_backward == 0.004) & (ds.stepsize == 0.008))]
ds = ds[(ds.loss_feedback != "L-DRL") | ((ds.loss_feedback == "L-DRL") & (ds.learning_rate == 0.2) & (ds.learning_rate_backward == 0.0004) & (ds.stepsize == 0.04))]
ds = ds[~ds.duplicated(subset=["Name", "loss_feedback", "seed", "learning_rate", "learning_rate_backward", "stepsize"])]
pd.pivot_table(ds, values='test accuracy', index=['algorithm', 'loss_feedback'], columns=['dataset'], aggfunc="mean")
# Out:
# dataset                  CIFAR10
# algorithm loss_feedback
# BP        DTP            0.53896
# DTP       DRL            0.45598
#           DTP            0.48800
#           L-DRL          0.45420
# DTP-BN    DTP            0.45256
# FWDTP     DTP            0.35800
# FWDTP-BN  DTP            0.50774

# %%
pd.pivot_table(ds, values='test accuracy', index=['algorithm', 'loss_feedback'], columns=['dataset'], aggfunc="std")
# Out:
# dataset                   CIFAR10
# algorithm loss_feedback
# BP        DTP            0.011425
# DTP       DRL            0.004532
#           DTP            0.006700
#           L-DRL          0.004201
# DTP-BN    DTP            0.005097
# FWDTP     DTP            0.001032
# FWDTP-BN  DTP            0.000918

# %%
ds = dataset[dataset["dataset"] == "CIFAR100"]
del ds["Runtime"]
ds["algorithm"].unique()
ds = ds[ds.epochs_backward == 5]
ds = ds[(ds.algorithm != "BP") | ((ds.algorithm == "BP") & (ds.learning_rate == 0.004))]
pd.pivot_table(ds[ds.algorithm == "BP"], values='test accuracy', index=['learning_rate'], columns=['dataset'], aggfunc="mean")
ds = ds[(ds.loss_feedback != "DRL") | ((ds.loss_feedback == "DRL") & (ds.learning_rate == 0.8) & (ds.learning_rate_backward == 0.002) & (ds.stepsize == 0.02))]
ds = ds[(ds.loss_feedback != "L-DRL") | ((ds.loss_feedback == "L-DRL") & (ds.learning_rate == 2) & (ds.learning_rate_backward == 0.0001) & (ds.stepsize == 0.008))]
ds = ds[~ds.duplicated(subset=["Name", "loss_feedback", "seed", "learning_rate", "learning_rate_backward", "stepsize"])]
pd.pivot_table(ds, values='test accuracy', index=['algorithm', 'loss_feedback'], columns=['dataset'], aggfunc="mean")
# Out:
# dataset                  CIFAR100
# algorithm loss_feedback
# BP        DTP            0.237025
# DTP       DRL            0.204780
#           DTP            0.229960
#           L-DRL          0.206260
# DTP-BN    DTP            0.181200
# FWDTP     DTP            0.153720
# FWDTP-BN  DTP            0.230440

# %%
pd.pivot_table(ds, values='test accuracy', index=['algorithm', 'loss_feedback'], columns=['dataset'], aggfunc="std")
# Out:
# dataset                  CIFAR100
# algorithm loss_feedback
# BP        DTP            0.002213
# DTP       DRL            0.001807
#           DTP            0.000856
#           L-DRL          0.001638
# DTP-BN    DTP            0.002082
# FWDTP     DTP            0.001192
# FWDTP-BN  DTP            0.001869

# %%
ds[(ds.algorithm=="BP") & (ds.learning_rate==0.004)]
# Out:
#             Name   dataset algorithm loss_feedback  test accuracy     State  \
# 11   CIFAR100_BP  CIFAR100        BP           DTP         0.2361  finished
# 41   CIFAR100_BP  CIFAR100        BP           DTP         0.2400  finished
# 168  CIFAR100_BP  CIFAR100        BP           DTP         0.2372  finished
# 393  CIFAR100_BP  CIFAR100        BP           DTP         0.2348  finished
#
#      learning_rate  learning_rate_backward  train accuracy  seed  \
# 11           0.004                   0.001         0.34102     5
# 41           0.004                   0.001         0.34256     2
# 168          0.004                   0.001         0.34252     3
# 393          0.004                   0.001         0.33832     4
#
#     activation_function  epochs_backward  stepsize
# 11                 tanh                5      0.01
# 41                 tanh                5      0.01
# 168                tanh                5      0.01
# 393                tanh                5      0.01

# %% [markdown]
# # CCL

# %%
# MNIST
PATH = "./wandb_classification_CCL_0502.csv"
dataset = pd.read_csv(PATH)
ds = dataset[dataset["dataset"] == "MNIST"]
# del ds["Runtime"]
ds = ds[ds.grad_clip_B == 1]
ds = ds[ds.grad_clip_F == 1]
ds = ds[ds.lr_B == 2]
ds = ds[ds.lr_F == 2]
ds = ds[ds.epochs == 100]
ds = ds[~ds.duplicated()]
ds = ds.dropna()
print(ds.test_acc.mean(), ds.test_acc.std())
# Out:
# 0.9815400000000001 0.0011107554986484476

# %%
# MNIST
PATH = "./wandb_classification_CCL_0502.csv"
dataset = pd.read_csv(PATH)
ds = dataset[dataset["dataset"] == "FashionMNIST"]
# del ds["Runtime"]
ds = ds[ds.grad_clip_B == 1]
ds = ds[ds.grad_clip_F == 1]
ds = ds[ds.lr_B == 2]
ds = ds[ds.lr_F == 2]
ds = ds[ds.epochs == 100]
ds = ds[~ds.duplicated()]
ds = ds.dropna()
print(ds.test_acc.mean(), ds.test_acc.std())
# Out:
# 0.879975 0.004778149671757301

# %%
# MNIST
PATH = "./wandb_classification_CCL_0502.csv"
dataset = pd.read_csv(PATH)
ds = dataset[dataset["dataset"] == "CIFAR10"]
# del ds["Runtime"]
ds = ds[ds.grad_clip_B == 1]
ds = ds[ds.grad_clip_F == 1]
ds = ds[ds.lr_B == 0.5]
ds = ds[ds.lr_F == 0.5]
ds = ds[ds.epochs == 100]
ds = ds[~ds.duplicated(subset=["dataset","act_B","grad_clip_B","seed","lr_B","lr_F"])]
ds = ds.dropna()
print(ds.test_acc.mean(), ds.test_acc.std())
# Out:
# 0.5212999999999999 0.0021319005605327707

# %%
# MNIST
PATH = "./wandb_classification_CCL_0502.csv"
dataset = pd.read_csv(PATH)
ds = dataset[dataset["dataset"] == "CIFAR100"]
# del ds["Runtime"]
ds = ds[ds.grad_clip_B == 1]
ds = ds[ds.grad_clip_F == 1]
ds = ds[ds.lr_B == 4]
ds = ds[ds.lr_F == 4]
ds = ds[ds.epochs == 100]
ds = ds[~ds.duplicated(subset=["dataset","act_B","grad_clip_B","seed","lr_B","lr_F"])]
ds = ds.dropna()
print(ds.test_acc.mean(), ds.test_acc.std())
# Out:
# 0.21653333333333333 0.0014571661996262998
